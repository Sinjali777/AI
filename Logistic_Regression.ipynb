# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinjali777/AI/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sigmoid

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

z = np.linspace(-10, 10, 100)
y = sigmoid(z)

plt.plot(z, y)
plt.xlabel("Input")
plt.ylabel("Probability")
plt.title("Sigmoid Function")
plt.show()

# %% [markdown]
# **Logistic Regression**

# %% [markdown]
# Student Pass Prediction

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

data = {
    "study_hours": [1,2,3,4,5,6,7,8],
    "pass": [0,0,0,0,1,1,1,1]
}

df = pd.DataFrame(data)

X = df[["study_hours"]]
y = df["pass"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

model = LogisticRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# Understanding Predictions

# %%
for h in [2, 4, 6, 8]:
    prob = model.predict_proba([[h]])[0][1]
    print(f"Study hours: {h}, Probability of passing: {prob:.2f}")
# Out:
# Study hours: 2, Probability of passing: 0.06
# Study hours: 4, Probability of passing: 0.34
# Study hours: 6, Probability of passing: 0.80
# Study hours: 8, Probability of passing: 0.97
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# The model is not just saying yes or no. Instead, it is saying how sure it is.

# %% [markdown]
# Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt

X_vals = np.linspace(0, 9, 100).reshape(-1,1)
y_vals = model.predict_proba(X_vals)[:,1]

plt.scatter(X["study_hours"], y)
plt.plot(X_vals, y_vals)
plt.xlabel("Study Hours")
plt.ylabel("Probability of Passing")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
